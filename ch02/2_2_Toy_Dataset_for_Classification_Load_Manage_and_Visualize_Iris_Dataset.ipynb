# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
from sklearn import datasets

# %%
iris = datasets.load_iris()
iris_df = pd.DataFrame(iris.data, columns = iris.feature_names)
iris_df.insert(0, "class", iris.target)

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   class              150 non-null    int64
#  1   sepal length (cm)  150 non-null    float64
#  2   sepal width (cm)   150 non-null    float64
#  3   petal length (cm)  150 non-null    float64
#  4   petal width (cm)   150 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
iris_df.head()
# Out:
#    class  sepal length (cm)  sepal width (cm)  petal length (cm)  \
# 0      0                5.1               3.5                1.4
# 1      0                4.9               3.0                1.4
# 2      0                4.7               3.2                1.3
# 3      0                4.6               3.1                1.5
# 4      0                5.0               3.6                1.4
#
#    petal width (cm)
# 0               0.2
# 1               0.2
# 2               0.2
# 3               0.2
# 4               0.2

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
iris_df.groupby("class").size()
# Out:
# class
# 0    50
# 1    50
# 2    50
# dtype: int64

# %%
iris_corr = iris_df.corr()

# %%
plt.figure(figsize=(10, 10))
colormap = sns.color_palette("rocket_r", as_cmap=True)
sns.heatmap(iris_corr, annot=True, cmap=colormap)
plt.show()

# %%
iris_corr["class"].drop(["class"]).sort_values(
    ascending = False).plot.bar(figsize=(5,5)) 
plt.show()

# %%
g = sns.pairplot(iris_df, hue="class", height=2, palette="rocket_r")

handles = g._legend_data.values()
labels = list(iris.target_names)

g._legend.remove()
g.fig.legend(handles=handles, labels=labels, loc='upper left', ncol=3)

# %%
fig, axs = plt.subplots(2, 1)
sns.violinplot(x="class", y="petal length (cm)", data=iris_df, size=5, palette='rocket_r', ax = axs[0])
sns.violinplot(x="class", y="petal width (cm)", data=iris_df, size=5, palette='rocket_r', ax = axs[1])
# Out:
# <AxesSubplot:xlabel='class', ylabel='petal width (cm)'>

# %%
iris_df[iris_df["class"] == 0].describe()
# Out:
#        class  sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count   50.0           50.00000         50.000000          50.000000
# mean     0.0            5.00600          3.428000           1.462000
# std      0.0            0.35249          0.379064           0.173664
# min      0.0            4.30000          2.300000           1.000000
# 25%      0.0            4.80000          3.200000           1.400000
# 50%      0.0            5.00000          3.400000           1.500000
# 75%      0.0            5.20000          3.675000           1.575000
# max      0.0            5.80000          4.400000           1.900000
#
#        petal width (cm)
# count         50.000000
# mean           0.246000
# std            0.105386
# min            0.100000
# 25%            0.200000
# 50%            0.200000
# 75%            0.300000
# max            0.600000

# %%
iris_df[iris_df["class"] == 1].describe()
# Out:
#        class  sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count   50.0          50.000000         50.000000          50.000000
# mean     1.0           5.936000          2.770000           4.260000
# std      0.0           0.516171          0.313798           0.469911
# min      1.0           4.900000          2.000000           3.000000
# 25%      1.0           5.600000          2.525000           4.000000
# 50%      1.0           5.900000          2.800000           4.350000
# 75%      1.0           6.300000          3.000000           4.600000
# max      1.0           7.000000          3.400000           5.100000
#
#        petal width (cm)
# count         50.000000
# mean           1.326000
# std            0.197753
# min            1.000000
# 25%            1.200000
# 50%            1.300000
# 75%            1.500000
# max            1.800000

# %%
iris_df[iris_df["class"] == 2].describe()
# Out:
#        class  sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count   50.0           50.00000         50.000000          50.000000
# mean     2.0            6.58800          2.974000           5.552000
# std      0.0            0.63588          0.322497           0.551895
# min      2.0            4.90000          2.200000           4.500000
# 25%      2.0            6.22500          2.800000           5.100000
# 50%      2.0            6.50000          3.000000           5.550000
# 75%      2.0            6.90000          3.175000           5.875000
# max      2.0            7.90000          3.800000           6.900000
#
#        petal width (cm)
# count          50.00000
# mean            2.02600
# std             0.27465
# min             1.40000
# 25%             1.80000
# 50%             2.00000
# 75%             2.30000
# max             2.50000
